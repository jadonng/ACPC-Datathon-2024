# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
meat_production_df = pd.read_csv("Data/Meat_Stats_Meat_Production.csv", index_col=0)
stock_df = pd.read_csv("Data/all_stock_and_etfs.csv", index_col=0)

# %%
meat_production_df.head(5)
# Out:
#           Year  Month            Unit Production Animal  \
# Date
# Dec-2023  2023     12  Million Pounds   2,189.80   Beef
# Nov-2023  2023     11  Million Pounds   2,280.90   Beef
# Oct-2023  2023     10  Million Pounds   2,340.90   Beef
# Sep-2023  2023      9  Million Pounds   2,149.40   Beef
# Aug-2023  2023      8  Million Pounds   2,363.50   Beef
#
#          Commercial or Federally Inspected Type of Meat
# Date
# Dec-2023                        Commercial     Red Meat
# Nov-2023                        Commercial     Red Meat
# Oct-2023                        Commercial     Red Meat
# Sep-2023                        Commercial     Red Meat
# Aug-2023                        Commercial     Red Meat

# %%
meat_production_df["Unit"].unique()
# Out:
# array(['Million Pounds'], dtype=object)

# %%
meat_production_df["Animal"].unique()
# Out:
# array(['Beef', 'Veal', 'Pork', 'Lamb and Mutton', 'Broilers',
#        'Other Chicken', 'Turkey'], dtype=object)

# %%
meat_production_df["Commercial or Federally Inspected"].unique()
# Out:
# array(['Commercial', 'Federally Inspected'], dtype=object)

# %% [markdown]
# # Meat Production Graphs

# %%
animal_list = meat_production_df["Animal"].unique().tolist()
try:
    meat_production_df['Production'] = meat_production_df['Production'].str.replace(',', '').astype(float)
except:
    pass

# %%
grouped_meat_df = meat_production_df.groupby(['Animal','Date']).sum()

# %%
grouped_meat_df.head(100)
# Out:
#                  Year  Month                          Unit  Production  \
# Animal Date
# Beef   Apr-1921  3842      8  Million PoundsMillion Pounds       316.0
#        Apr-1922  3844      8  Million PoundsMillion Pounds       332.0
#        Apr-1923  3846      8  Million PoundsMillion Pounds       372.0
#        Apr-1924  3848      8  Million PoundsMillion Pounds       357.0
#        Apr-1925  3850      8  Million PoundsMillion Pounds       389.0
# ...               ...    ...                           ...         ...
#        Apr-2016  4032      8  Million PoundsMillion Pounds      3903.8
#        Apr-2017  4034      8  Million PoundsMillion Pounds      3900.0
#        Apr-2018  4036      8  Million PoundsMillion Pounds      4207.1
#        Apr-2019  4038      8  Million PoundsMillion Pounds      4495.7
#        Apr-2020  4040      8  Million PoundsMillion Pounds      3599.3
#
#                 Commercial or Federally Inspected      Type of Meat
# Animal Date
# Beef   Apr-1921     CommercialFederally Inspected  Red MeatRed Meat
#        Apr-1922     CommercialFederally Inspected  Red MeatRed Meat
#        Apr-1923     CommercialFederally Inspected  Red MeatRed Meat
#        Apr-1924     CommercialFederally Inspected  Red MeatRed Meat
#        Apr-1925     CommercialFederally Inspected  Red MeatRed Meat
# ...                                           ...               ...
#        Apr-2016     CommercialFederally Inspected  Red MeatRed Meat
#        Apr-2017     CommercialFederally Inspected  Red MeatRed Meat
#        Apr-2018     CommercialFederally Inspected  Red MeatRed Meat
#        Apr-2019     CommercialFederally Inspected  Red MeatRed Meat
#        Apr-2020     CommercialFederally Inspected  Red MeatRed Meat
#
# [100 rows x 6 columns]

# %%
animal_names = grouped_meat_df.index.get_level_values('Animal').unique()
print(animal_names)
# Out:
# Index(['Beef', 'Broilers', 'Lamb and Mutton', 'Other Chicken', 'Pork',
#        'Turkey', 'Veal'],
#       dtype='object', name='Animal')

# %%
for animal in animal_list:
    plot_df = grouped_meat_df[grouped_meat_df.index.get_level_values('Animal') == animal]
    plot_df.index = pd.to_datetime(plot_df.index.get_level_values('Date'))
    plot_df = plot_df.sort_index()
    plt.plot(plot_df.index, plot_df['Production'], label=animal)

total_production_df = meat_production_df.groupby(['Date']).sum()
total_production_df.index = pd.to_datetime(total_production_df.index.get_level_values('Date'))
total_production_df = total_production_df.sort_index()
plt.plot(total_production_df.index, total_production_df['Production'], label="Total", color="Black", alpha=0.5)

plt.legend()
plt.xlabel('Date')
plt.ylabel('Production')
plt.title('Meat Production')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\anson\AppData\Local\Temp\ipykernel_14452\3555494765.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   plot_df.index = pd.to_datetime(plot_df.index.get_level_values('Date'))
# C:\Users\anson\AppData\Local\Temp\ipykernel_14452\3555494765.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   plot_df.index = pd.to_datetime(plot_df.index.get_level_values('Date'))
# C:\Users\anson\AppData\Local\Temp\ipykernel_14452\3555494765.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   plot_df.index = pd.to_datetime(plot_df.index.get_level_values('Date'))
# C:\Users\anson\AppData\Local\Temp\ipykernel_14452\3555494765.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   plot_df.index = pd.to_datetime(plot_df.index.get_level_values('Date'))
# C:\Users\anson\AppData\Local\Temp\ipykernel_14452\3555494765.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   plot_df.index = pd.to_datetime(plot_df.index.get_level_values('Date'))
# C:\Users\anson\AppData\Local\Temp\ipykernel_14452\3555494765.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   plot_df.index = pd.to_datetime(plot_df.index.get_level_values('Date'))
# C:\Users\anson\AppData\Local\Temp\ipykernel_14452\3555494765.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   plot_df.index = pd.to_datetime(plot_df.index.get_level_values('Date'))
# C:\Users\anson\AppData\Local\Temp\ipykernel_14452\3555494765.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   total_production_df.index = pd.to_datetime(total_production_df.index.get_level_values('Date'))

# %% [markdown]
# # Stock Graphs

# %%
display(stock_df)
# Out:
#              Open     High      Low  Close   Volume Ticker_Symbol
# Date-Time
# 2024-02-20  29.09  29.7100  29.0001  29.44  2673889           HRL
# 2024-02-16  29.01  29.1700  28.7650  28.99  5655091           HRL
# 2024-02-15  28.94  29.2210  28.8500  29.11  2380372           HRL
# 2024-02-14  28.76  28.8254  28.5100  28.80  2690379           HRL
# 2024-02-13  29.56  29.8000  28.6350  28.72  4173650           HRL
# ...           ...      ...      ...    ...      ...           ...
# 1999-11-05   9.25   9.5000   9.2500   9.50     2300           ALG
# 1999-11-04   9.31   9.4400   9.3100   9.31     1100           ALG
# 1999-11-03   9.00   9.2500   9.0000   9.19    35000           ALG
# 1999-11-02   8.75   8.8800   8.6200   8.88     7700           ALG
# 1999-11-01   8.38   8.7500   8.3800   8.75     7400           ALG
#
# [163557 rows x 6 columns]

# %%
stock_df["Ticker_Symbol"].unique()
# Out:
# array(['HRL', 'VOO', 'ADM', 'AGCO', 'DIA', 'PEP', 'QSR', 'TSCO', 'ONEQ',
#        'PPC', 'CAG', 'DRI', 'HSY', 'CAT', 'SBUX', 'CMG', 'COKE', 'CNHI',
#        'SPY', 'DE', 'TSN', 'GIS', 'WEN', 'YUM', 'VMI', 'MCD', 'SAP',
#        'DPZ', 'ALG'], dtype=object)

# %%
stock_des = pd.read_csv("Data/stock_descriptions.csv", index_col=0)

# %%
display(stock_des)
# Out:
#            AssetType                                         Name  \
# Symbol
# QSR     Common Stock          Restaurant Brands International Inc
# ALG     Common Stock                              Alamo Group Inc
# SBUX    Common Stock                        Starbucks Corporation
# CAG     Common Stock                            ConAgra Foods Inc
# HRL     Common Stock                     Hormel Foods Corporation
# DPZ     Common Stock                           Domino’s Pizza Inc
# CMG     Common Stock                   Chipotle Mexican Grill Inc
# DRI     Common Stock                       Darden Restaurants Inc
# GIS     Common Stock                            General Mills Inc
# TSCO    Common Stock                       Tractor Supply Company
# MCD     Common Stock                       McDonald’s Corporation
# PPC     Common Stock                          Pilgrims Pride Corp
# VMI     Common Stock                       Valmont Industries Inc
# YUM     Common Stock                              Yum! Brands Inc
# SAP     Common Stock                                   SAP SE ADR
# HSY     Common Stock                                   Hershey Co
# ADM     Common Stock               Archer-Daniels-Midland Company
# TSN     Common Stock                              Tyson Foods Inc
# AGCO    Common Stock                             AGCO Corporation
# KDP     Common Stock                         Keurig Dr Pepper Inc
# PEP     Common Stock                                  PepsiCo Inc
# CNHI    Common Stock                          CNH Industrial N.V.
# MNST    Common Stock                        Monster Beverage Corp
# WEN     Common Stock                               The Wendy’s Co
# DE      Common Stock                              Deere & Company
# CAT     Common Stock                              Caterpillar Inc
# COKE    Common Stock                  Coca-Cola Consolidated Inc.
# DIA              ETF  SPDR Dow Jones Industrial Average ETF Trust
# ONEQ             ETF          Fidelity Nasdaq Composite Index ETF
# SPY              ETF                 SPDR S&P 500 ETF Trust (SPY)
# VOO              ETF                Vanguard 500 Index Fund (VOO)
#
#                                               Description            Sector  \
# Symbol
# QSR     Restaurant Brands International Inc. owns, ope...  TRADE & SERVICES
# ALG     Alamo Group Inc. designs, manufactures, distri...        TECHNOLOGY
# SBUX    Starbucks Corporation is an American multinati...  TRADE & SERVICES
# CAG     Conagra Brands, Inc. (formerly ConAgra Foods) ...     MANUFACTURING
# HRL     Hormel Foods Corporation is an American compan...     MANUFACTURING
# DPZ     Domino's Pizza, Inc., branded as Domino's, is ...  TRADE & SERVICES
# CMG     Chipotle Mexican Grill, Inc., often known simp...  TRADE & SERVICES
# DRI     Darden Restaurants, Inc. is an American multi-...  TRADE & SERVICES
# GIS     General Mills, Inc., is an American multinatio...     MANUFACTURING
# TSCO    Tractor Supply Company (TSCO) is an American r...  TRADE & SERVICES
# MCD     McDonald's Corporation is an American fast foo...  TRADE & SERVICES
# PPC     Pilgrim's Pride Corporation produces, processe...     MANUFACTURING
# VMI     Valmont Industries, Inc. produces and sells me...     MANUFACTURING
# YUM     Yum! Brands, Inc. is an American fast food cor...  TRADE & SERVICES
# SAP     SAP SE is a global enterprise application soft...        TECHNOLOGY
# HSY     The Hershey Company, commonly known as Hershey...     MANUFACTURING
# ADM     The Archer-Daniels-Midland Company, commonly k...     MANUFACTURING
# TSN     Tyson Foods, Inc. is an American multinational...     MANUFACTURING
# AGCO    AGCO Corporation manufactures and distributes ...        TECHNOLOGY
# KDP     Keurig Dr Pepper Inc. is a beverage company in...     MANUFACTURING
# PEP     PepsiCo, Inc. is an American based multination...     MANUFACTURING
# CNHI    CNH Industrial NV designs, produces, markets, ...        TECHNOLOGY
# MNST    Monster Beverage Corporation is an American be...     MANUFACTURING
# WEN     The Wendy's Company, is a quick service restau...  TRADE & SERVICES
# DE      John Deere is the brand name of Deere & Compan...        TECHNOLOGY
# CAT     Caterpillar Inc. (often shortened to CAT) is a...        TECHNOLOGY
# COKE    Coca-Cola Consolidated, Inc. produces, markets...     MANUFACTURING
# DIA     The DIA stock price tracks the performance of ...          MULTIPLE
# ONEQ    The ONEQ stock price tracks the performance of...          MULTIPLE
# SPY     The SPY stock price tracks the performance of ...          MULTIPLE
# VOO     The VOO stock price tracks the performance of ...          MULTIPLE
#
#                                                  Industry
# Symbol
# QSR                                  RETAIL-EATING PLACES
# ALG                            FARM MACHINERY & EQUIPMENT
# SBUX                      RETAIL-EATING & DRINKING PLACES
# CAG                             FOOD AND KINDRED PRODUCTS
# HRL                                   MEAT PACKING PLANTS
# DPZ                WHOLESALE-GROCERIES & RELATED PRODUCTS
# CMG                                  RETAIL-EATING PLACES
# DRI                                  RETAIL-EATING PLACES
# GIS                                   GRAIN MILL PRODUCTS
# TSCO    RETAIL-BUILDING MATERIALS, HARDWARE, GARDEN SU...
# MCD                                  RETAIL-EATING PLACES
# PPC                   POULTRY SLAUGHTERING AND PROCESSING
# VMI                  FABRICATED STRUCTURAL METAL PRODUCTS
# YUM                                  RETAIL-EATING PLACES
# SAP                         SERVICES-PREPACKAGED SOFTWARE
# HSY                        SUGAR & CONFECTIONERY PRODUCTS
# ADM                                           FATS & OILS
# TSN                   POULTRY SLAUGHTERING AND PROCESSING
# AGCO                           FARM MACHINERY & EQUIPMENT
# KDP                                             BEVERAGES
# PEP                                             BEVERAGES
# CNHI                       CONSTRUCTION MACHINERY & EQUIP
# MNST     BOTTLED & CANNED SOFT DRINKS & CARBONATED WATERS
# WEN                       RETAIL-EATING & DRINKING PLACES
# DE                             FARM MACHINERY & EQUIPMENT
# CAT                        CONSTRUCTION MACHINERY & EQUIP
# COKE     BOTTLED & CANNED SOFT DRINKS & CARBONATED WATERS
# DIA                                              MULTIPLE
# ONEQ                                             MULTIPLE
# SPY                                              MULTIPLE
# VOO                                              MULTIPLE
